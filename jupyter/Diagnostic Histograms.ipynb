# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# rij,rik,rkl,rjl,xi_ik[i],xi_jl,c4v,prob

# %%
M=10000
rij,rik,rkl,rjl,xi_ik,xi_jl,rik_mu,rjl_mu,cont,prob=[np.zeros(M) for _ in range(10)]
with open("../testing.dat","r") as testfile:
    for l,line in enumerate(testfile):
        if l<10000:
            split_line=line.split("\t")
            rij[l]=float(split_line[0])
            rik[l]=float(split_line[1])
            rik_mu[l]=float(split_line[2])
            rkl[l]=float(split_line[3])
            rjl[l]=float(split_line[4])
            rjl_mu[l]=float(split_line[5])
            xi_ik[l]=float(split_line[6])
            xi_jl[l]=float(split_line[7])
            cont[l]=float(split_line[8])
            prob[l]=float(split_line[9].split("\n")[0])

# %%
plt.hist(np.log10(np.abs(cont)),bins=100);

# %%
plt.scatter(rik,xi_ik,s=1,c=rik_mu)
plt.yscale('log');
plt.ylim([0.0001,1])
plt.colorbar();

# %%
plt.scatter(rjl,xi_jl,s=1,c=rjl_mu)
plt.yscale('log');
plt.ylim([0.0001,1])
plt.colorbar();

# %%
plt.scatter(rij,rik,s=1,c=np.log10(np.abs(cont)))
plt.colorbar()
