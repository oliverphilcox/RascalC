# %%
# First load xi(r) kernel
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
xi_data=np.loadtxt('../xi_functions/QPM_Mash.xi',skiprows=2)
xi_r=np.genfromtxt('../xi_functions/QPM_Mash.xi',max_rows=1)
xi_mu=np.genfromtxt('../xi_functions/QPM_Mash.xi',skip_header=1,max_rows=1)

# %%
from scipy.interpolate import interp2d
def xi_2d(r,mu):
    R,MU=np.meshgrid(xi_r,xi_mu)
    print R.shape
    out=interp2d(xi_data.T,R,MU)
    return out(r,mu)

# %%
r = np.linspace(0.1,200)
mus=np.linspace(0,1,5)
for mu in mus:
    plt.plot(r,xi_2d(r,mu))
# Out:
# (120, 180)
# /home/oliver/anaconda2/lib/python2.7/site-packages/scipy/interpolate/_fitpack_impl.py:976: RuntimeWarning: No more knots can be added because the additional knot would
# coincide with an old one. Probable cause: s too small or too large
# a weight to an inaccurate data point. (fp>s)
# 	kx,ky=1,1 nx,ny=4,255 m=21600 fp=210.084649 s=0.000000
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))
# (120, 180)
# (120, 180)
# (120, 180)
# (120, 180)

# %%
R,MU=np.meshgrid(xi_r,xi_mu)

# %%
xi1d=xi_data.mean(axis=1)
for i in range(120):
    plt.plot(xi_r,xi_data[:,i]*xi_r*xi_r)

# %%
plt.plot(xi_r,xi1d*xi_r**2.)
plt.plot(xi_r,max(xi1d)*np.ones_like(xi_r))

# %%
xi_test=np.abs(xi1d+1./xi_r**(2.))
plt.plot(xi_r,xi_test*xi_r**2.)
plt.plot(xi_r,xi1d*xi_r**2.)
#plt.yscale('log')
#plt.xscale('log')
