# %%
import sys
sys.path.insert(0, '../../wcdm/')
import wcdm

# %%
wcdm.test()
# Out:
# Testing the base wcdm code
# LCDM, om=0.3, z=1: r(z) =  0.7714270664268946  Err =  -1.0996759058912176e-12
# WCDM, om=0.3, w=-0.2, z=1: r(z) =  0.6260536546214  Err =  -4.670819286900496e-12
# WCDM, om=0.3, w=-0.4, z=1: r(z) =  0.6657559503028381  Err =  -2.7198243657267085e-12
# WCDM, om=0.3, w=-1.4, z=1: r(z) =  0.8253597172730941  Err =  -2.3968493856330042e-11
# WCDM, om=1.3, w=-0.4, z=1: r(z) =  0.5611308930173824  Err =  -3.226041656034795e-11
#
# Testing the owcdm code in the flat limit
# Non-flat LCDM, om=0.3, ok=0, z=1: r(z) =  0.7714270664268946  Err =  -1.0996759058912176e-12
# Non-flat WCDM, om=0.3, w=-0.4, ok=0, z=1: r(z) =  0.6657559503028381  Err =  -2.7198243657267085e-12
# Non-flat WCDM, om=0.3, w=-1.4, ok=0, z=1: r(z) =  0.8253597172730941  Err =  -2.3968493856330042e-11
#
# Slightly open universes
# Non-flat LCDM, om=0.3, ok=0.05, z=1: r(z) =  0.7601558556727533  Err =  7.598036644296258e-10
# ...
