# %%
# %pylab inline
prob_file = '/home/oliverphilcox/COMAJE/tmp_prob_cube.txt'
prob_arr=np.genfromtxt(prob_file,max_rows=10000)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
p = prob_arr[:,1]
dis = prob_arr[:,0]

# %%
plt.errorbar(dis,p*dis*dis,marker='x',ls='')
plt.xlim([0,400])
# Out:
# (0, 400)

# %%
plt.errorbar(dis,p,ls='',marker='x')
# Out:
# <ErrorbarContainer object of 3 artists>
