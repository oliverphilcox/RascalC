# %%
# %pylab inline
correct=np.diag(np.loadtxt('../test_one_l/c3_n9_m3_full.txt'))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
multi_l_filled_grid=np.diag(np.loadtxt('../Test_allL/c3_n9_m3_full.txt'))

# %%
#multi_l_all=np.loadtxt('../CovMatricesAll/c4_n36_m10_full.txt')

# %%
plt.plot(correct,label='Initial')
plt.plot(multi_l_filled_grid,label='Multi_l_filled')
#plt.plot(np.diag(multi_l_all),label='Multi_l_all')
plt.yscale('log');plt.legend();

# %%
plt.plot(correct/multi_l_filled_grid)

# %%
x=np.mean(correct/multi_l_filled_grid)

# %%
x
# Out:
# 1.6485201407071637

# %%
n_try=8.72e6
n_acc=8.65e6
n_integ=8.91e6
n_samples=1.2e8
n_sln=11382606

# %%
n_sln/1e6
# Out:
# 11.382606

# %%
x*1.86e-4*n_integ
# Out:
# 2269.8220536488534
