# %%
# %pylab inline
import re,os
n=18
max_l=6
in_root = '/mnt/store1/oliverphilcox/3PCF_QPM_v3/SE_out_ITC/qpm'
in_root2 = '/mnt/store1/oliverphilcox/3PCF_QPM_v3/SE_out_General/qpm'
rand_it = 32
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def xi_reader(in_str,root1=True):
    
    if root1:
        file_name = in_root+'.'+in_str+'.out'
    else:
        file_name = in_root2+'.'+in_str+'.out'

    dat = np.zeros([n,1])

    if not os.path.exists(file_name):
        return dat
    
    with open(file_name) as f:
        start=False
        for line in f:
            if not start:
                if re.match("# Binned",line):
                    start=True
                continue
            if len(line.split())==0:
                start=False
                continue
            if re.match('# Multipole',line):
                start=False
                continue
            x=line.split()
            b=int(x[1])
            dat[b,0]=float(x[2])
            
    return dat;
    
def check_dat(arr):
    if np.isfinite(arr.sum()):
        if np.sum(np.abs(arr))>0:
            if np.sum(np.abs(arr))<1e10:
                return True
    else:
        return False

# %%
rr=xi_reader('0.rrr',True)

all_xi = []
good_mocks = []

for mock_no in range(300):
    
    if not os.path.exists(in_root+'.%d.nnn_%d.out'%(mock_no,rand_it-1)):
        if not os.path.exists(in_root2+'.%d.nnn_%d.out'%(mock_no,rand_it-1)):
            continue;

    all_nn=[]
    for i in range(rand_it):
        tmp_in = xi_reader('%d.nnn_%d'%(mock_no,i))
        if not check_dat(tmp_in):
            # Check second directory
            tmp_in = xi_reader('%d.nnn_%d'%(mock_no,i),False)
        if check_dat(tmp_in):
            all_nn.append(tmp_in)
    
    if len(all_nn)!=rand_it:
        continue
        
    this_nn = np.mean(all_nn,axis=0)
    
    this_xi = this_nn/rr
    
    if check_dat(this_xi):
        all_xi.append(this_xi)
        good_mocks.append(mock_no)
    
all_xi = np.asarray(all_xi)
n_mocks1 = len(all_xi)
print("N_mocks = %d"%n_mocks1)
# Out:
# N_mocks = 273

# %%
xi_in = '/mnt/store1/oliverphilcox/QPM_xi/QPM_mean.xi'
xi_r = np.genfromtxt(xi_in,max_rows=1)
xi_dat = np.genfromtxt(xi_in,skip_header=2)

# %%
r_bins = np.arange(5,180,10)
delta_r = r_bins[1]-r_bins[0]
r_min = r_bins-delta_r/2
min_r_bin = 7

# %%
mean_xi = all_xi.mean(axis=0)
std_xi = all_xi.std(axis=0)
plt.errorbar(r_bins,r_bins**2*mean_xi[:,0],yerr=r_bins**2*std_xi[:,0]/np.sqrt(n_mocks1))
plt.plot(xi_r,xi_r**2*xi_dat.mean(axis=1))

# %%
def reader(in_str,root1=True):
    
    if root1:
        file_name = in_root+'.'+in_str+'.out'
    else:
        file_name = in_root2+'.'+in_str+'.out'
    
    dat = np.zeros([n,n,max_l+1])

    if not os.path.exists(file_name):
        return dat
    
    with open(file_name) as f:
        start=False
        for line in f:
            if not start:
                if re.match("# Multipole",line):
                    start=True
                continue
            if re.match("Multipole",line):
                continue
            if len(line.split())==0:
                start=False
                continue
            if re.match('# Saving',line):
                start=False
                continue
            x=line.split()
            b1=int(x[0])
            b2=int(x[1])
            dat[b1,b2,0]=float(x[2])/2.
            if b1!=b2:
                dat[b2,b1,0]=float(x[2])/2.
            for ell in range(1,max_l+1):
                dat[b1,b2,ell]=float(x[ell+2])*float(x[2])*(2.*ell+1.)/2.
                if b1!=b2:
                    dat[b2,b1,ell]=float(x[ell+2])*float(x[2])*(2.*ell+1.)/2.
    return dat;

# %%
rrr=reader('0.rrr',True)

all_zeta_uncorr = []
good_mocks2 = []

for mock_no in range(300):
    
    if mock_no not in good_mocks:
        continue

    all_n=[]
    for i in range(rand_it):
        tmp_in = reader('%d.nnn_%d'%(mock_no,i))
        if not check_dat(tmp_in):
            # Check second directory
            tmp_in = reader('%d.nnn_%d'%(mock_no,i),False)
        if check_dat(tmp_in):
            all_n.append(tmp_in)
    
    if len(all_n)!=rand_it:
        continue
    
    this_nnn = np.mean(all_n,axis=0)
    
    this_zeta = this_nnn/rrr[:,:,0].reshape(n,n,1)
    
    if check_dat(this_zeta):
        all_zeta_uncorr.append(this_zeta)
        good_mocks2.append(mock_no)
    
all_zeta_uncorr = np.asarray(all_zeta_uncorr)
n_mocks1 = len(all_zeta_uncorr)
print("N_mocks = %d"%n_mocks1)
# Out:
# /home/oliverphilcox/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:36: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# N_mocks = 245

# %%
r_bins = np.arange(5,180,10)
delta_r = r_bins[1]-r_bins[0]
r_min = r_bins-delta_r/2
min_r_bin = 7

f = rrr

from sympy.physics.wigner import wigner_3j

def Mjl_calc(j,ell,flist):
    s=0
    for ellprime in np.arange(1,len(flist)):
        s+=wigner_3j(ell,ellprime,j,0,0,0)**2*flist[ellprime]
    s*=(2*j+1)
    return s    

f[:,:,:]/=f[:,:,0].reshape((n,n,1))

all_Mjl=[]
for b1 in range(len(r_bins)):
    for b2 in range(len(r_bins)):
            
        Mjl = np.zeros((max_l+1,max_l+1))
        for j in range(max_l+1):
            for k in range(max_l+1):
                Mjl[j][k]=Mjl_calc(j,k,f[b1,b2,:])
        all_Mjl.append(Mjl)

# %%
r_bins = np.arange(5,180,10)
delta_r = r_bins[1]-r_bins[0]
r_min = r_bins-delta_r/2
min_r_bin = 7

all_zeta = []

for mock_no in range(n_mocks1):
    
    this_zeta = np.zeros([n,n,max_l+1])
    
    print('Window-correcting mock %d of %d'%(mock_no+1,n_mocks1))
    
    ind=0
    for b1 in range(len(r_bins)):
        for b2 in range(len(r_bins)):
            
            Mjl=all_Mjl[ind]
            ind+=1
            
            geometry = np.linalg.inv(np.identity(max_l+1)+Mjl)
            
            this_zeta[b1,b2,:] = geometry.dot(all_zeta_uncorr[mock_no,b1,b2,:])

    all_zeta.append(this_zeta)
# Out:
# Window-correcting mock 1 of 245
# Window-correcting mock 2 of 245
# Window-correcting mock 3 of 245
# Window-correcting mock 4 of 245
# Window-correcting mock 5 of 245
# Window-correcting mock 6 of 245
# Window-correcting mock 7 of 245
# Window-correcting mock 8 of 245
# Window-correcting mock 9 of 245
# Window-correcting mock 10 of 245
# Window-correcting mock 11 of 245
# Window-correcting mock 12 of 245
# Window-correcting mock 13 of 245
# Window-correcting mock 14 of 245
# Window-correcting mock 15 of 245
# Window-correcting mock 16 of 245
# Window-correcting mock 17 of 245
# Window-correcting mock 18 of 245
# Window-correcting mock 19 of 245
# Window-correcting mock 20 of 245
# Window-correcting mock 21 of 245
# Window-correcting mock 22 of 245
# Window-correcting mock 23 of 245
# Window-correcting mock 24 of 245
# Window-correcting mock 25 of 245
# Window-correcting mock 26 of 245
# Window-correcting mock 27 of 245
# Window-correcting mock 28 of 245
# Window-correcting mock 29 of 245
# Window-correcting mock 30 of 245
# Window-correcting mock 31 of 245
# Window-correcting mock 32 of 245
# Window-correcting mock 33 of 245
# Window-correcting mock 34 of 245
# Window-correcting mock 35 of 245
# Window-correcting mock 36 of 245
# Window-correcting mock 37 of 245
# Window-correcting mock 38 of 245
# Window-correcting mock 39 of 245
# Window-correcting mock 40 of 245
# Window-correcting mock 41 of 245
# Window-correcting mock 42 of 245
# Window-correcting mock 43 of 245
# Window-correcting mock 44 of 245
# Window-correcting mock 45 of 245
# Window-correcting mock 46 of 245
# Window-correcting mock 47 of 245
# Window-correcting mock 48 of 245
# Window-correcting mock 49 of 245
# Window-correcting mock 50 of 245
# Window-correcting mock 51 of 245
# Window-correcting mock 52 of 245
# Window-correcting mock 53 of 245
# Window-correcting mock 54 of 245
# Window-correcting mock 55 of 245
# Window-correcting mock 56 of 245
# Window-correcting mock 57 of 245
# Window-correcting mock 58 of 245
# Window-correcting mock 59 of 245
# Window-correcting mock 60 of 245
# Window-correcting mock 61 of 245
# Window-correcting mock 62 of 245
# Window-correcting mock 63 of 245
# Window-correcting mock 64 of 245
# Window-correcting mock 65 of 245
# Window-correcting mock 66 of 245
# Window-correcting mock 67 of 245
# Window-correcting mock 68 of 245
# Window-correcting mock 69 of 245
# Window-correcting mock 70 of 245
# Window-correcting mock 71 of 245
# Window-correcting mock 72 of 245
# Window-correcting mock 73 of 245
# Window-correcting mock 74 of 245
# Window-correcting mock 75 of 245
# Window-correcting mock 76 of 245
# Window-correcting mock 77 of 245
# Window-correcting mock 78 of 245
# Window-correcting mock 79 of 245
# Window-correcting mock 80 of 245
# Window-correcting mock 81 of 245
# Window-correcting mock 82 of 245
# Window-correcting mock 83 of 245
# Window-correcting mock 84 of 245
# Window-correcting mock 85 of 245
# Window-correcting mock 86 of 245
# Window-correcting mock 87 of 245
# Window-correcting mock 88 of 245
# Window-correcting mock 89 of 245
# Window-correcting mock 90 of 245
# Window-correcting mock 91 of 245
# Window-correcting mock 92 of 245
# Window-correcting mock 93 of 245
# Window-correcting mock 94 of 245
# Window-correcting mock 95 of 245
# Window-correcting mock 96 of 245
# Window-correcting mock 97 of 245
# Window-correcting mock 98 of 245
# Window-correcting mock 99 of 245
# Window-correcting mock 100 of 245
# Window-correcting mock 101 of 245
# Window-correcting mock 102 of 245
# Window-correcting mock 103 of 245
# Window-correcting mock 104 of 245
# Window-correcting mock 105 of 245
# Window-correcting mock 106 of 245
# Window-correcting mock 107 of 245
# Window-correcting mock 108 of 245
# Window-correcting mock 109 of 245
# Window-correcting mock 110 of 245
# Window-correcting mock 111 of 245
# Window-correcting mock 112 of 245
# Window-correcting mock 113 of 245
# Window-correcting mock 114 of 245
# Window-correcting mock 115 of 245
# Window-correcting mock 116 of 245
# Window-correcting mock 117 of 245
# Window-correcting mock 118 of 245
# Window-correcting mock 119 of 245
# Window-correcting mock 120 of 245
# Window-correcting mock 121 of 245
# Window-correcting mock 122 of 245
# Window-correcting mock 123 of 245
# Window-correcting mock 124 of 245
# Window-correcting mock 125 of 245
# Window-correcting mock 126 of 245
# Window-correcting mock 127 of 245
# Window-correcting mock 128 of 245
# Window-correcting mock 129 of 245
# Window-correcting mock 130 of 245
# Window-correcting mock 131 of 245
# Window-correcting mock 132 of 245
# Window-correcting mock 133 of 245
# Window-correcting mock 134 of 245
# Window-correcting mock 135 of 245
# Window-correcting mock 136 of 245
# Window-correcting mock 137 of 245
# Window-correcting mock 138 of 245
# Window-correcting mock 139 of 245
# Window-correcting mock 140 of 245
# Window-correcting mock 141 of 245
# Window-correcting mock 142 of 245
# Window-correcting mock 143 of 245
# Window-correcting mock 144 of 245
# Window-correcting mock 145 of 245
# Window-correcting mock 146 of 245
# Window-correcting mock 147 of 245
# Window-correcting mock 148 of 245
# Window-correcting mock 149 of 245
# Window-correcting mock 150 of 245
# Window-correcting mock 151 of 245
# Window-correcting mock 152 of 245
# Window-correcting mock 153 of 245
# Window-correcting mock 154 of 245
# Window-correcting mock 155 of 245
# Window-correcting mock 156 of 245
# Window-correcting mock 157 of 245
# Window-correcting mock 158 of 245
# Window-correcting mock 159 of 245
# Window-correcting mock 160 of 245
# Window-correcting mock 161 of 245
# Window-correcting mock 162 of 245
# Window-correcting mock 163 of 245
# Window-correcting mock 164 of 245
# Window-correcting mock 165 of 245
# Window-correcting mock 166 of 245
# Window-correcting mock 167 of 245
# Window-correcting mock 168 of 245
# Window-correcting mock 169 of 245
# Window-correcting mock 170 of 245
# Window-correcting mock 171 of 245
# Window-correcting mock 172 of 245
# Window-correcting mock 173 of 245
# Window-correcting mock 174 of 245
# Window-correcting mock 175 of 245
# Window-correcting mock 176 of 245
# Window-correcting mock 177 of 245
# Window-correcting mock 178 of 245
# Window-correcting mock 179 of 245
# Window-correcting mock 180 of 245
# Window-correcting mock 181 of 245
# Window-correcting mock 182 of 245
# Window-correcting mock 183 of 245
# Window-correcting mock 184 of 245
# Window-correcting mock 185 of 245
# Window-correcting mock 186 of 245
# Window-correcting mock 187 of 245
# Window-correcting mock 188 of 245
# Window-correcting mock 189 of 245
# Window-correcting mock 190 of 245
# Window-correcting mock 191 of 245
# Window-correcting mock 192 of 245
# Window-correcting mock 193 of 245
# Window-correcting mock 194 of 245
# Window-correcting mock 195 of 245
# Window-correcting mock 196 of 245
# Window-correcting mock 197 of 245
# Window-correcting mock 198 of 245
# Window-correcting mock 199 of 245
# Window-correcting mock 200 of 245
# Window-correcting mock 201 of 245
# Window-correcting mock 202 of 245
# Window-correcting mock 203 of 245
# Window-correcting mock 204 of 245
# Window-correcting mock 205 of 245
# Window-correcting mock 206 of 245
# Window-correcting mock 207 of 245
# Window-correcting mock 208 of 245
# Window-correcting mock 209 of 245
# Window-correcting mock 210 of 245
# Window-correcting mock 211 of 245
# Window-correcting mock 212 of 245
# Window-correcting mock 213 of 245
# Window-correcting mock 214 of 245
# Window-correcting mock 215 of 245
# Window-correcting mock 216 of 245
# Window-correcting mock 217 of 245
# Window-correcting mock 218 of 245
# Window-correcting mock 219 of 245
# Window-correcting mock 220 of 245
# Window-correcting mock 221 of 245
# Window-correcting mock 222 of 245
# Window-correcting mock 223 of 245
# Window-correcting mock 224 of 245
# Window-correcting mock 225 of 245
# Window-correcting mock 226 of 245
# Window-correcting mock 227 of 245
# Window-correcting mock 228 of 245
# Window-correcting mock 229 of 245
# Window-correcting mock 230 of 245
# Window-correcting mock 231 of 245
# Window-correcting mock 232 of 245
# Window-correcting mock 233 of 245
# Window-correcting mock 234 of 245
# Window-correcting mock 235 of 245
# Window-correcting mock 236 of 245
# Window-correcting mock 237 of 245
# Window-correcting mock 238 of 245
# Window-correcting mock 239 of 245
# Window-correcting mock 240 of 245
# Window-correcting mock 241 of 245
# Window-correcting mock 242 of 245
# Window-correcting mock 243 of 245
# Window-correcting mock 244 of 245
# Window-correcting mock 245 of 245

# %%
all_zeta = np.asarray(all_zeta)
n_mocks = len(all_zeta)

# %% [markdown]
# ## Check Q ratio

# %% [markdown]
# #### Get Q approximation

# %%
from scipy.interpolate import UnivariateSpline
spl = UnivariateSpline(xi_r,xi_r**2*xi_dat.mean(axis=1),s=1)

xi_fun = lambda r: spl(r)/r**2

# %%
from scipy.special import legendre

mu_arr = np.arange(-1.,1.,0.05)

all_Q = np.zeros([n,n,len(mu_arr)])

for b1 in range(n):
    for b2 in range(n):
        if b1==b2:
            continue
        r1 = r_bins[b1]
        r2 = r_bins[b2]

        this_zeta = all_zeta.mean(axis=0)[b1,b2]

        r3_arr = np.sqrt(r2**2+r1**2-2*r1*r2*mu_arr)

        xi_12 = xi_fun(r1)*xi_fun(r2)*np.ones_like(r3_arr)

        ells = np.arange(max_l+1)

        this_zeta_mu = np.zeros(len(mu_arr))

        for ell in ells:
            this_zeta_mu+=legendre(ell)(mu_arr)*this_zeta[ell]

        this_Q = this_zeta_mu/(xi_12+xi_fun(r1)*xi_fun(r3_arr)+xi_fun(r2)*xi_fun(r3_arr))
        
        all_Q[b1,b2]=this_Q

# %% [markdown]
# ## Compress Q ratio

# %%
r_bins = np.arange(5,180,10)
delta_r = r_bins[1]-r_bins[0]
r_min = r_bins-delta_r/2
min_r_bin = 7

vol_r = 4.*np.pi/3.*((r_min+delta_r)**3-r_min**3)

Q_compress = np.zeros([n-min_r_bin,len(mu_arr)])

denom = np.zeros([n-min_r_bin])

for b1 in range(min_r_bin,n):
    for b2 in range(3,b1-3):
        Q_compress[b1-min_r_bin,:]+=all_Q[b1,b2,:]*vol_r[b2]
        denom[b1-min_r_bin]+=vol_r[b2]
    Q_compress[b1-min_r_bin,:]/=denom[b1-min_r_bin]

# %%
for i in range(len(Q_compress)-6):
    plt.plot(mu_arr,Q_compress[i],label=r'$%d-%d$ Mpc/h'%(r_min[min_r_bin+i],r_min[min_r_bin+i+1]))
plt.legend(fontsize=12)
#plt.ylim([-20,60])
plt.ylabel(r'Hierarchical Ratio $Q^{(c)}$',fontsize=18);plt.xlabel(r' Triangle angle $\chi$',fontsize=16);

# %%
for i in range(len(Q_compress)-6):
    plt.plot(mu_arr,Q_compress[i],label=r'$%d-%d$ Mpc/h'%(r_min[min_r_bin+i],r_min[min_r_bin+i+1]))
plt.legend(fontsize=12)
#plt.ylim([-20,60])
plt.ylabel(r'Hierarchical Ratio $Q^{(c)}$',fontsize=18);plt.xlabel(r' Triangle angle $\chi$',fontsize=16);

# %%
plt.plot(mu_arr,all_Q[6,5])

# %% [markdown]
# #### Compress 3PCF

# %%
r_bins = np.arange(5,180,10)
delta_r = r_bins[1]-r_bins[0]
r_min = r_bins-delta_r/2
min_r_bin = 7

vol_r = 4.*np.pi/3.*((r_min+delta_r)**3-r_min**3)

zeta_compress = np.zeros([n_mocks1,n-min_r_bin,max_l+1])

for i in range(n_mocks):
    denom = np.zeros([n-min_r_bin])

    for b1 in range(min_r_bin,n):
        for b2 in range(3,b1-3):
            zeta_compress[i,b1-min_r_bin,:]+=all_zeta[i,b1,b2,:]*vol_r[b2]
            denom[b1-min_r_bin]+=vol_r[b2]
        zeta_compress[i,b1-min_r_bin,:]/=denom[b1-min_r_bin]

# %%
for ell in range(max_l+1):
    plt.errorbar(r_bins[min_r_bin:],(r_bins[min_r_bin:]/10)**4*zeta_compress.mean(axis=0)[:,ell],
                 (r_bins[min_r_bin:]/10.)**4*zeta_compress.std(axis=0)[:,ell]/np.sqrt(n_mocks),label=r'$\ell=%d$'%ell)
plt.legend();
plt.ylabel(r'$(r/10)^4\zeta^{(c)}_\ell(r)$',fontsize=16);
plt.xlabel(r'$r$',fontsize=16);

# %%
np.savez('plot_data/3PCF_compressed_plot.npz',max_l=max_l,r_bins=r_bins,
        min_r_bin=min_r_bin,zeta_compress=zeta_compress,n_mocks=n_mocks,)

# %%
for ell in range(max_l+1):
    plt.errorbar(r_bins[min_r_bin:],(r_bins[min_r_bin:]/10)**4*zeta_compress.mean(axis=0)[:,ell],
                 (r_bins[min_r_bin:]/10.)**4*zeta_compress.std(axis=0)[:,ell]/np.sqrt(n_mocks),label=r'$\ell=%d$'%ell)
plt.legend();
plt.ylabel(r'$(r/10)^4\zeta^{(c)}_\ell(r)$',fontsize=16);
plt.xlabel(r'$r$',fontsize=16);

# %%
all_N_gal = np.load('/mnt/store1/oliverphilcox/3PCF_QPM_v3/all_N_gal.npy')
these_N_gal = all_N_gal[good_mocks2]

# %%
zeta_compress_flat=[]
for i in range(n_mocks):
    zeta_compress_flat.append(zeta_compress[i].T.ravel())
zeta_compress_flat=np.asarray(zeta_compress_flat)

cov_zeta = np.cov(zeta_compress_flat.T)#,aweights=these_N_gal/np.mean(these_N_gal))

# %%
def plotter(mat,vmax=np.inf,perc=99,rmax=0):
    if vmax==np.inf:
        vmax=np.percentile(mat,perc)
    plt.matshow(mat,vmax=vmax,vmin=-vmax,cmap=cm.RdBu_r);
    plt.colorbar();
    if rmax==0:
        rmax = len(mat)
    plt.ylim([-0.5,rmax-0.5])
    plt.xlim([-0.5,rmax-0.5])

# %% [markdown]
# ## Load theory:

# %%
theory = np.load('/mnt/store1/oliverphilcox/3PCF_QPM_v3/combined_compressed_qpm_theory.npz')
c3=theory['c3']
c4=theory['c4']
c5=theory['c5']
c6=theory['c6']-theory['c60']
c_theory = c3+c4+c5+c6

# %%
max_l = 6
n_mat = len(r_bins[min_r_bin:])
sample_cov = cov_zeta[:(max_l+1)*n_mat,:(max_l+1)*n_mat]
theory_cov = c_theory[:(max_l+1)*n_mat,:(max_l+1)*n_mat]

# %%
r_all = np.concatenate([r_bins[min_r_bin:] for _ in range(max_l+1)])
r_mat = np.matmul((r_all**2).reshape(-1,1),(r_all**2).reshape(1,-1))

# %%
from scipy.optimize import minimize

def cov_model(alpha):
    return (c3*alpha**3+c4*alpha**2+c5*alpha+c6)[:(max_l+1)*n_mat,:(max_l+1)*n_mat]


def KL_div_lin(alpha):
    c_th = cov_model(alpha)
    prec = np.linalg.inv(c_th)
    slog1 = np.linalg.slogdet(prec)
    if slog1[0]<0:
        return np.inf
    slog2 = np.linalg.slogdet(sample_cov)
    if slog2[0]<0:
        return np.inf
    return 0.5*(np.trace(np.matmul(sample_cov,prec))-slog1[1]-slog2[1]-len(sample_cov))

start_x = 1.1
x=minimize(KL_div_lin,start_x)

if x.success and x.x!=start_x:
    print("Success with alpha = %.4f, KL = %.2f"%(x.x,KL_div_lin(x.x)))
    c_opt = cov_model(x.x)
else:
    print("Could not fit - using alpha = 1.5")
    c_opt = cov_model(1.8)#*2
# Out:
# Success with alpha = 1.2618, KL = 7.89

# %%
def KL_div_2d(par):
    alpha,rescale=par
    c_th = rescale*cov_model(alpha)
    prec = np.linalg.inv(c_th)
    slog1 = np.linalg.slogdet(prec)
    if slog1[0]<0:
        return np.inf
    slog2 = np.linalg.slogdet(sample_cov)
    if slog2[0]<0:
        return np.inf
    return 0.5*(np.trace(np.matmul(sample_cov,prec))-slog1[1]-slog2[1]-len(sample_cov))


start_x = [1.1,1.]
x=minimize(KL_div_2d,start_x)

if x.success and x.x[0]!=start_x[0]:
    print("Success with alpha = %.4f, rescale = %.4f, KL = %.2f"%(x.x[0],x.x[1],KL_div_2d(x.x)))
    c_opt = cov_model(x.x[0])*x.x[1]
else:
    print("Could not fit - using alpha = 1.5")
    c_opt = cov_model(1.8)#*2
# Out:
# Success with alpha = 1.0059, rescale = 1.3294, KL = 7.59

# %%
n_bins = len(c_opt)
exp_KL = n_bins*(n_bins+1)/4.*(1./theory['n_eff']+1./n_mocks)
print("Expected KL divergence: %.2f"%exp_KL)
# Out:
# Expected KL divergence: 6.33

# %%
exp_KL
# Out:
# 6.332255403250639

# %% [markdown]
# ## NB: We can probably lower alpha by ~10% by changing the galaxy normalization to mean $N_\mathrm{gal}$ not first galaxy

# %% [markdown]
# ## Add a global renormalization

# %%
plotter(sample_cov,vmax=4e-8)
plotter(c_opt,vmax=4e-8)

# %%
alphas = np.arange(0.9,2.5,0.05)
divs = [KL_div_lin(al) for al in alphas]
plt.plot(alphas,divs)

# %%
plt.plot(np.diag(sample_cov));
plt.plot(np.diag(c_opt))
plt.yscale('log');

# %%
plt.plot(np.diag(c_opt/sample_cov))

# %%
plt.plot(np.diag(c3))
plt.plot(np.diag(c4))
plt.plot(np.diag(c5))
plt.plot(np.diag(c6))
plt.plot(np.diag(sample_cov))
plt.yscale('log')

# %%
plotter(sample_cov*r_mat,vmax=3)
plotter(c_opt*r_mat,vmax=3)
plotter((sample_cov-c_opt)*r_mat)

# %%
plt.plot(np.diag(sample_cov),label=r'Mocks')
plt.plot(np.diag(c_opt),label=r'Theory')
plt.yscale('log')
plt.legend(fontsize=14);
plt.xlabel(r'Bin Number')
plt.ylabel(r'$\mathrm{diag}(C_{ab})$',fontsize=16);

# %%
plt.plot(np.diag(sample_cov/c_opt))

# %%
def reduce(mat):
    out_mat = np.zeros_like(mat)
    for i in range(len(mat)):
        for j in range(len(mat)):
            out_mat[i,j]=mat[i,j]/np.sqrt(mat[i,i]*mat[j,j])
    return out_mat

# %%
plotter(reduce(sample_cov))
plotter(reduce(c_opt))

# %%
D_mat = (len(sample_cov)+1.)/(n_mocks-1.)
prec_theory=np.linalg.inv(c_opt)
prec_obs = np.linalg.inv(sample_cov)*(1.-D_mat)

# %%
plotter(prec_obs/r_mat,vmax=2)
plotter(prec_theory/r_mat,vmax=2)
plotter((prec_theory-prec_obs)/r_mat)

# %%
chol = np.linalg.cholesky(sample_cov)
disc = np.matmul(chol.T,np.matmul(prec_theory,chol))-np.eye(len(prec_theory))
plotter((disc))

# %%
np.savez('plot_data/cov_matrices.npz',sample_cov=sample_cov,c_opt=c_opt,r_mat=r_mat,prec_obs=prec_obs,
        prec_theory=prec_theory,disc=disc)

# %%
mean_disc=np.mean(np.tril(disc))*100
rms_disc = np.std(np.tril(disc))*100
DoF = len(cov_zeta)
print("mean: %.2f rms: %.2f"%(mean_disc,rms_disc))
print("Expected RMS: %.2f"%(DoF/np.sqrt(n_mocks)))
# Out:
# mean: -0.03 rms: 5.10
# Expected RMS: 4.92
